# %%
import dlib
import cv2
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dlib
import cv2
import json

# %%
image = cv2.imread("2.jpg")
h,w = image.shape[:2]
plt.imshow(image)

# %%
m1 = cv2.getRotationMatrix2D((w/2,h/2), 45,1) # 45도 회전
rotatedImage = cv2.warpAffine(image,m1,(w,h))
plt.imshow(rotatedImage)
